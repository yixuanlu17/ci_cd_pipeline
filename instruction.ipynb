# %% [markdown]
# ## Lab Summary
#
# In this lab, participants will explore the fundamentals of a CI/CD pipeline using GitHub Actions and Docker. They will create and configure a GitHub Actions workflow on a dedicated branch, commit changes, and observe the various stages of the workflow execution directly in their GitHub repository. Upon successful execution, they will download the Docker image built by the pipeline, deploy it locally as a container, and test the deployed serving layer using the provided test_model.py script.

# %% [markdown]
# ### Lab Objectives
#
# By the end of this lab, participants will be able to:
#
# - Understand GitHub Actions Workflow
# - Explore GitHub Workflow Stages
# - Download and Run the Docker Image Locally
# - Test the Deployed Serving Layer
# - Understand the CI/CD Workflow

# %% [markdown]
# ## Create your own sample github workflow
#
# Run the below code, it will prompt you to enter your name.
#
# - It will create workflow file with your name
# - Also, model/scaler file will be created with your name and uploaded to S3
# - Finally docker image will also get created with your name

# %% [markdown]
# Step 1: Login to your github account

# %% [markdown]
# #### Above changes will trigger ci/cd pipeline in github repo
#
# Login to github repo. Credentails will be provided by instructor at runtime
#
# Go to [www.git](https://github.com/) and click on Sign in
#
# Go to ![image.png](attachment:image.png)

# %% [markdown]
# ### Now enter email address and password provided by instructor and then click on Sign In
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Once logged in, Click Ci_cd_pipeline Repo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### On Main Repo page, if you click on main, you will find your branch name.Now click on ACtions to see your workflow.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### On Action page, select your branch to look your workflow
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Once you click on your branch, it will filter out workflow that is triggered by your change. Click on workflow name..
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Once you click on your workflow, it will show you all steps in yur workflow. Click on each steps to explore more
#
# - Explore build_and_test stage
#     - In this stage we run all unit test cases
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Explore build_and_test stage
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### To explore the next stage. click on build_model
#
# - In this stage, we train the model and save the model artifacts on aws s3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Finally explore the last stage deploy_serving_layer
#
# - In this stage, we download the model artifact back from aws s3 and create a docker image and save image in dockerhub repo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Finally you can try running a container with your deployed image

# %%
# sample command
# docker pull technoavengers/model_serving_navdeep
# docker run -p 8089:8000 -d technoavengers/model_serving_navdeep

#Pull your deployed image on local 

# !docker pull model_serving_<replace_it_with_your_name>

# Run a container

# !docker run -p 8085:8000 -d model_serving_<replace_it_with_your_name>

# %%
# !docker ps

# %% [markdown]
# #### Test your model

# %%
# !python test_model.py

# %% [markdown]
# ### Congratulations. You have successfully completed your lab
